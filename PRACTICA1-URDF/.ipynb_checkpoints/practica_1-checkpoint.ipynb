# %% [markdown]
# # Práctica 1: Visualización de un modelo URDF
#
# ## Objetivo
#
# El objetivo de esta práctica es que el alumno comprenda, interprete y modifique la información básica de los formatos de Universal Robot Description File (URDF).
#
#
# ### Metas
#
# - Que el alumno comprenda la estructura básica de un archivo URDF.
# - Que el alumno sea capaz de mofificar la información básica de los archivos URDF para modificar la descripción de un robot serial.
# - Que el alumno sea capaz de vizualizar un robot descrito en un archivo URDF mediante la aplicación de RVIZ.
# - Que el alumno configure un repositorio en línea e incluya en éste su práctica
#
# ### Contribución al perfil del egresado
#
# La siguiente práctica contribuye en los siguientes puntos al perfil del egresado:
#
# #### Aptitudes y habilidades
#
# - Para modelar, simular e interpretar el comportamiento de los sistemas mecatrónicos.
# - Para desarrollar, operar y mantener procesos productivos que impliquen la transformación de materia, energía e información.
# - Para diseñar, construir, operar y mantener los sistemas mecatrónicos y sus componentes.
#
# #### Actitudes
#
# - Ser creativo e innovador.
# - Tener confianza en su preparación académica.
# - Comprometido con su actualización, superación y competencia profesional.
#
# #### De tipo social
#
# - Promover el cambio en la mentalidad frente a la competitividad internacional.
#
#
#
# ## Rúbrica de evaluación
#
# La evaluación de la práctica contará de los siguientes puntos y se evaluará con los siguientes criterios:
#
# | Elemento | Porcentaje |
# | ------:| ----------- |
# | **Cuestionario previo** | 15% |
# | **Desarrollo** | 35% |
# | **Análisis de resultados**  | 35% |
# | **Conclusiones** | 15% |
#
# | Elemento | Malo | Regular | Bueno |
# | ------:| ------ | --------| ------|
# | **Cuestionario previo** | El trabajo no contiene cuestionario previo o todas las preguntas son incorrectas (0%)| Al menos la mitad de las preguntas son correctas (8%) |  Todas las preguntas son correctas (15%) |
# | **Desarrollo** | El trabajo no contiene desarrollo o su planteamiento no concuerda con lo deseado (0%) | El desarrollo está mal planteado o no llega a los resultados esperados (10%) | El desarrollo tiene un planteamiento adecuado y llega a los resultados esperados (35%) |
# | **Análisis de resultados**  | El trabajo no contiene análisis de resultados o la información no se está interpretando correctamente (0%) | La interpretación de los resultados es parcial o desorganizada (10%) | Realiza un correcto análisis de los resultados de forma organizada   (35%) |
# | **Conclusiones** | El trabajo no contiene conclusiones o no hacen referencia al trabajo desarrollado y los objetivos planteados (0%) | La redacción de las conclusiones es desorganizada o confusa (8%) | Las conclusiones del trabajo son claras y hacen referencia al trabajo desarrollado y los objetivos planteados (15%) |

# %% [markdown]
# # Introducción
#
# ## Jupyter
# Jupyter es una aplicación interactiva basada en web que permite crear documentos que contienen código ejecutable, texto con formato, ecuaciones, visualizaciones y otros elementos interactivos. Es ampliamente utilizado en ciencia de datos, machine learning, análisis de datos y educación.
#
# ### Formato de texto
#
# - Los títulos y subtítulos se usan agregando un "#" y un espacio al inicio del párrafo
# # Título
# ## Subtítulo 1
# ### Subtítulo 2
# -  Se pueden crear listas usando el símbolo "-" ó "*" al inicio de un párrafo
#
# - Para hacer niveles dentro de la lista, se debe dejar un nivel de indentación antes del símbolo de la lista
# - Nivel 1
#   - Nivel 3
#     - Nivel 3
# - Para utilizar catracteres especiales, se utiliza el caracter de escape "\\"
#   - ### Subtítulo
#   -  \### No es subtítulo
# - Se puede dar formato al texto encerrando entre "*"
#   - *itálica*  --->  \*itálica*
#   - **negrita**  --->  \*\*negrita**
#   - ***negrita itálica***  --->  \*\*\*negrita itálica***
#
#
# ### Tablas
#
# Para incluir tablas, se utilizan los símbolos "|, -"
#
# ```text
#  | Nombre  | Edad | Ciudad      |
#  |---------|------|------------|
#  | Juan    | 25   | Madrid     |
#  | María   | 30   | Barcelona  |
#  | Carlos  | 28   | Valencia   |
#
# ```
#
#  | Nombre  | Edad | Ciudad      |
#  |---------|------|------------|
#  | Juan    | 25   | Madrid     |
#  | María   | 30   | Barcelona  |
#  | Carlos  | 28   | Valencia   |
#
# ** También puedes alinear el texto dentro de las columnas:
#
# ```text
#  | Nombre  | Edad | Ciudad      |
#  |:--------|:----:|------------:|
#  | Juan    | 25   | Madrid     |
#  | María   | 30   | Barcelona  |
#  | Carlos  | 28   | Valencia   |
#
#  izquierda  centrado  derecha
#
# ```
#
#  | Nombre  | Edad | Ciudad      |
#  |:--------|:----:|------------:|
#  | Juan    | 25   | Madrid     |
#  | María   | 30   | Barcelona  |
#  | Carlos  | 28   | Valencia   |
#
# ### Hipervínculos
#  Puedes agregar enlaces usando la siguiente sintaxis:
#
#  > \[Texto del enlace](https://www.ejemplo.com)
#
#  Ejemplo:
#
#  [Página de Jupyter](https://jupyter.org)
# ### Imágenes
#
# Se pueden incluir imágenes dentro de un archivo markdown a través de una nomenclatura propia de jupyter o como una inserción html. Se pueden agregar como una ruta que hace referencia a un archivo del repositorio o como una URL
#
# > \<img src="imagenes/p1_1.png" alt = "RViz" width="100" height="100" display= "block"/>
#
# > \!\[RVIZ](imagenes/p1_1.png)
#
# <img src="imagenes/p1_1.png" alt = "RViz" width="100" height="100" display= "block"/>
#
# ### Código
# Para incluir código en una celda Markdown, usa triple acento grave (```) seguido del lenguaje:
#
# >\```python
# >
# >#Código de python
# >
# >\```
#
#
#  Por ejemplo:
#  ```python
#  print("Hola, mundo")
#  ```
# ### LaTeX
#
# Para incluir ecuaciones en sistema LaTeX usando el símbolo doble "\$\$":
#
#  $$E = mc^2$$
#
#  ** También puedes escribir ecuaciones en línea con un solo símbolo: $F = ma$
#
#
# ### Emoticones
# - Puedes usar emoticones en Markdown con GitHub-style emoji codes:
#
#  - :smile: → 😄  `:smile:`
#  - :thumbsup: → 👍  `:thumbsup:`
#  - :rocket: → 🚀  `:rocket:`
#  - :star: → ⭐  `:star:`
#  - :heart: → ❤️  `:heart:`
#
# **Los emojis no se muestran en jupyter, sólo en VSCode ó Github, pero se pueden copiar los emojis desde otra ubicación, pegarlos, y se desplegarán correctamente: [Página de emojis](https://getemoji.com/)
#
# Comunmente se usan emojis y medallas en los archivos "README.MD" para indicar información sobre los repositorios en github (Usar el archivo README.MD de este repositorio como referencia)

# %% [markdown]
# ### URDF (Unified Robot Description Format):
# El URDF es un formato de archivo XML que se utiliza para describir la estructura de un robot, comunmente usado en ROS. Permite definir la composición física de un robot, incluyendo sus eslabones y juntas. Además, permite especificar características como el peso, la geometría, y la disposición espacial de los elementos del robot.
#
# Los elementos primitivos son formas geométricas básicas que se utilizan para representar las partes de un robot en URDF. Algunos de los más comunes son:
#
# - **Caja (box)**: Un paralelepípedo definido por su ancho, alto y profundidad.
# - **Cilindro (cylinder)**: Definido por su radio y longitud.
# - **Esfera (sphere)**: Definida por su radio.
# - **Malla (mesh)**: Permite importar geometrías más complejas en formatos como STL, Collada, obj, entre otros.
#
# En el formato URDF, existen varios tipos de juntas que pueden definir el movimiento relativo entre las partes de un robot:
#
# - **Junta fija**: No permite ningún movimiento entre los elementos conectados.
# - **Junta rotacional**: Permite un movimiento de rotación alrededor de un eje.
# - **Junta prismática**: Permite un movimiento lineal a lo largo de un eje.
# - **Junta continua**: Es una variación de la junta rotacional que permite una rotación sin límites.
#
# ### RVIZ
# RViz (ROS Visualization) es una herramienta gráfica dentro del ecosistema de ROS que permite visualizar una amplia gama de información generada por robots. Esta herramienta es esencial para depurar, entender y visualizar los datos que se generan en tiempo real durante la simulación o la operación de un robot en un entorno físico.
#
# <img src="imagenes/p1_1.png" alt = "RViz" width="600" height="600" display= "block"/>
#
#
# RViz soporta muchos tipos de visualizaciones, en este caso veremos:
#
# - **Modelos 3D del robot (URDF)**: Puedes cargar y visualizar la descripción del robot usando su archivo URDF (Unified Robot Description Format). Esto te permite ver un modelo 3D del robot y observar cómo se mueve cada parte del robot (es decir, los eslabones y las juntas). También puedes ver cómo se actualiza en tiempo real cuando el robot cambia de posición.
#
# - **Transformaciones (TF)**: ROS utiliza un sistema de coordenadas llamado TF (transformación de marcos) para definir la relación espacial entre diferentes partes del robot y el entorno. En RViz, puedes visualizar estos sistemas de referencia y las transformaciones entre ellos, lo que es útil para entender cómo se mueven y orientan los diferentes componentes del robot.
# Esto incluye visualizar el origen de coordenadas del robot y sus partes móviles.

# %% [markdown]
# ## Cuestionario previo
#
# Responder de forma breve las siguientes preguntas:
#
# - ¿Que es jupyter? R: Es una aplicación interactiva basada en web que permite crear y ejecutar documentos llamados cuadernos (notebooks). Estos documentos combinan código ejecutable, texto con formato, ecuaciones matemáticas y visualizaciones en un solo entorno, lo que los hace ideales para aplicaciones en ciencia de datos, machine learning, simulación y educación. Jupyter es multiplataforma y admite múltiples lenguajes de programación, aunque es más comúnmente asociado con Python. Cuenta con herramientas avanzadas como JupyterLab, que ofrece una interfaz modular para trabajar con varios archivos y terminales, y JupyterHub, que permite el acceso simultáneo de múltiples usuarios en un servidor.
#
# <div align="center">
# <img src="imagenes/p1_4.png" alt = "JUP" width="600" height="600" display= "block"/>
# </div>
#
# - ¿Qué es un archivo URDF? R: El URDF (Unified Robot Description Format) es un formato basado en XML utilizado en ROS (Robot Operating System) para describir la estructura física de un robot. Este formato permite definir de manera precisa la geometría, cinemática y dinámica de un robot, incluyendo detalles sobre sus eslabones (links), juntas (joints), peso, geometría y la disposición espacial de sus partes. Los eslabones representan las partes rígidas del robot, como brazos o bases, mientras que las juntas definen cómo estos eslabones están conectados y cómo pueden moverse. Además, incluye propiedades físicas como colisiones, inercia y materiales. Este formato es fundamental en el ecosistema de ROS, ya que se utiliza para visualizar robots en herramientas como RVIZ, simular su comportamiento en entornos como Gazebo y facilitar la planificación y control de movimientos.
#
# <div align="center">
# <img src="imagenes/p1_5.png" alt = "JUP" width="600" height="600" display= "block"/>
# </div>
#
# - ¿Qué es git y github? R: Git es un sistema de control de versiones distribuido que permite gestionar cambios en el código fuente de manera eficiente. Con Git, los desarrolladores pueden trabajar en ramas independientes, registrar cambios mediante commits y mantener un historial completo del proyecto. GitHub, por otro lado, es una plataforma en línea basada en Git que facilita el alojamiento de repositorios y la colaboración en proyectos de software, además, ofrece herramientas como issues para gestionar tareas, pull requests para revisar y fusionar cambios, y GitHub Actions para automatizar tareas. Es ampliamente utilizado en proyectos de código abierto, fomentando la colaboración y el intercambio de conocimiento. Juntos, Git y GitHub son esenciales para el desarrollo moderno de software, ya que permiten gestionar versiones, coordinar el trabajo en equipo y mantener un historial completo de cambios.
#
# <div align="center">
# <img src="imagenes/p1_6.png" alt = "JUP" width="600" height="600" display= "block"/>
# </div>
#
# - ¿Que es RVIZ? R: RViz (ROS Visualization) es una herramienta de visualización gráfica en ROS (Robot Operating System) que permite observar modelos 3D de robots, transformaciones (TF), y otros datos en tiempo real, esta herramienta es esencial para la depuración, simulación y comprensión del comportamiento de robots, ya que proporciona una interfaz interactiva para visualizar información compleja de manera intuitiva. RViz permite cargar modelos de robots descritos en formato URDF, mostrar datos de sensores como nubes de puntos y mapas, y visualizar las relaciones espaciales entre los componentes del robot mediante el sistema de transformaciones (TF). Cabe señalar que su interfaz es altamente configurable y se integra directamente con los nodos de ROS, lo que lo convierte en una herramienta indispensable para el desarrollo y la investigación en robótica. Su capacidad para trabajar en conjunto con herramientas como Gazebo y MoveIt amplía aún más su utilidad en aplicaciones de simulación y planificación de movimientos.
#
# <div align="center">
# <img src="imagenes/p1_7.png" alt = "JUP" width="600" height="600" display= "block"/>
# </div>
#
#
# En caso de integrar imagenes, colocarlas en la carpeta *"Imagenes_P1"*

# %% [markdown]
# ## Desarrollo
#
# ### 1. Creación de un modelo URDF
# En este primera parte, se creará un archivo URDF de un robot tipo RRR con la siguiente disposición:
# <div align="center">
# <img src="imagenes/p1_2.png" alt = "Robot RRR" width="300" height="300"/>
# </div>
#
# ** Se pueden utilizar formas geométricas sencillas
# ** Mantener las dimensiones menores a 0.5 \[m].
#
# ### 2. Despliegue de un modelo URDF con configuraciones predeterminadas en RViz
# En esta segunda parte, se tomará el archivo URDF realizado y se desplegará en RViz utilizando algunas configuraciones predeterminadas.
# Para desplegar el archivo en RViz, se deben instalar algunas librerías:
#
# Para descargar condiguraciones de despliegue de modelos URDF
# > $ sudo apt-get install ros-humble-urdf-tutorial
#
# Instalar la librería que permite a ROS manipular los URDF (xacro)
# > $ sudo apt install ros-humble-xacro
#
# Ahora, hay que modificar el archivo. RViz requiere que las juntas tengan límites definidos, agregando el parámetro
# ``` xml
# <limit effort="XX" velocity="XX" lower="XX" upper="XX" />
# ```
# Siendo "XX" los valores deseados para cada parámetro.
#
# Con estos cambios, se puede correr el despliegue del modelo con un archivo *.launch del paquete urdf-tutorial
#
# > $ ros2 launch urdf_tutorial display.launch.py model:=/home/robousr/\<ruta_del_modelo\>/<nombre_del_modelo\>.urdf
#
# Agregar una imagen del modelo desplegado en RViz
#
# <div align="center">
# <img src="imagenes/p1_3.jpeg" alt = "Primer despliegue en RViz" width="900" height="900" display= "block"/>
# </div>

# %% [markdown]
# ### 3. Github
#
# Para terminar, crear un repositorio en línea en gihub, donde se subirán los archivos de la práctica.
# Se recomienda primero crear el repositorio en línea, clonarlo en el ordenador y después incluir los archivos de la práctica.
# En la configuración del repositorio incluir  un archivo README.md, y en él colocar:
#
# - Una descripción del repositorio
# - Nombres de los integrantes del equipo
#
# Para utilizar el repositorio para todas las prácticas posteriores, se recomienda usar la siguiente estructura de archivos:
# ~~~ bash
# Robotica2025-2/
# ├── practica_1
# │   ├── images
# │   │   └── p1_1.png
# │   └── practica_1.ipynb
# └── README.md
# ~~~
# JupyterLab crea carpetas ocultas de nombre **".ipynb_checkpoints/"** con la versión anterior de los archivos que carga. Para evitar que estas versiones estén en el repositorio, agregaremos un archivo de configuración **".gitignore"**
#
# El archivo debe estar en la raíz del repositorio. Para las carpetas que queremos omitir, el archivo debe tener un renglón:
#
# > \*\*/.ipynb_checkpoints/\*
#
# **Se puede usar como referencia el archivo **".gitignore"** de este repositorio

# %% [markdown]
# ## Análisis de resultados
#
# ¿Qué utilidad tiene el uso de un repositorio en línea para código?
# > RESPUESTA Un repositorio en línea facilita la colaboración, gestión de versiones y respaldo del código. Permite a varios desarrolladores trabajar simultáneamente en un proyecto, mantener un historial de cambios y contribuir de forma organizada.
#
# ¿Cuál es la convención de ángulos que utilizan los archivos URDF para los ángulos de las juntas respecto al eslabón padre?
# > RESPUESTA Los archivos URDF utilizan una convención de ángulos en el sistema de referencia local del eslabón padre. Los movimientos angulares se definen en función de los ejes XYZ locales del eslabón padre, respetando las especificaciones definidas en las juntas rotacionales o prismáticas.
#
#
# ¿Qué utilidad tiene describir un robot en un archivo URDF?
# > RESPUESTA Describir un robot en un archivo URDF es útil para visualizar su estructura, simular su movimiento en herramientas como RViz, y facilitar su integración en ROS. Permite definir eslabones, juntas y transformaciones necesarias para simular comportamientos reales.

# %% [markdown]
# ## Conclusiones
#
# ### NAHUATLATO JUAREZ WILBERT MIGUEL
# La creación y modificación de un archivo URDF nos permitió profundizar en la comprensión de la estructura de robots seriales y sus configuraciones básicas, facilitando la visualización de su comportamiento mediante la herramienta RViz. Esta experiencia también nos mostró la importancia de la representación gráfica y su impacto en la depuración y validación del diseño del robot en entornos simulados. Además, la implementación de un repositorio en GitHub contribuyó a fomentar la organización y colaboración en equipo, asegurando un flujo de trabajo eficiente y el respaldo adecuado de nuestros avances. En conjunto, estos elementos fortalecen no solo nuestra preparación técnica, sino también nuestra capacidad para trabajar de manera colaborativa y profesional en proyectos complejos relacionados con robótica y automatización.
#
# ### MARTIN SANTIAGO MAITE AIRIN
# A lo largo de esta práctica, nos fue posible comprender y aplicar los conceptos fundamentales relacionados con el formato URDF (Universal Robot Description File), así como su integración con herramientas esenciales en el desarrollo de sistemas robóticos. Mediante la creación y modificación de un archivo URDF, exploramos la estructura básica de este formato, identificando los elementos clave como eslabones (links) y juntas (joints), y cómo estos definen la geometría y cinemática de un robot serial, así mismo, la visualización del modelo en RViz nos permitió validar la correcta descripción del robot y comprender la importancia de esta herramienta en la depuración y simulación de sistemas robóticos. Además, la configuración de un repositorio en GitHub no solo nos facilitó la gestión del código y documentación, sino que también nos ayudó a reforzar habilidades en el uso de sistemas de control de versiones que nos servirán para continuar colaborando en equipo en el futuro.
#
# ### MENDEZ LOPEZ VALERIA MICHELLE
# Con la práctica se nos presentó una oportunidad para integrar conocimientos teóricos y prácticos en el ámbito de la robótica, específicamente en la descripción y visualización de robots mediante el formato URDF, a través de la creación y modificación del archivo, nos fue posible evidenciar la importancia de este formato como un estándar en la definición de la estructura física y funcional de un robot. La interacción con RViz permitió no solo visualizar el modelo creado, sino también comprender cómo esta herramienta facilita la interpretación de datos complejos en tiempo real, lo cual es importante para el desarrollo y depuración de sistemas robóticos, por otro lado, la creación de un repositorio en GitHub destacó la relevancia de las buenas prácticas en la gestión de proyectos, promoviendo la organización, colaboración y documentación adecuada.
#
# ## Bibliografía
#
# [1] F. Reyes Cortés, Robótica: Control de robots manipuladores, Alfaomega, 2019.
#
# [2] J. J. Craig, Introducción a la robótica: Mecánica y control (3ª ed.), Pearson Educación, México, 2006.
#
# [3] S. K. Saha, Introducción a la Robótica, 2ª ed., McGraw-Hill, 2014.
